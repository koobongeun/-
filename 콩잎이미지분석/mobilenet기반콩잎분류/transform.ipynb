# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np

ori_path = 'C:/Users/y2363/OneDrive/Desktop/Tic/archive/train/bean leaf/' 
save_path = 'C:/Users/y2363/OneDrive/Desktop/Tic/archive/train_transform/transform_bean_leaf'
file_list = os.listdir(ori_path)
print (file_list)

img_path = ori_path + file_list[1]
print(img_path)
img = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
cv2.threshold(img, 100, 255, cv2.THRESH_TOZERO)[1]
# cv2.imshow('',img)
plt.imshow(img)
# for file in file_list:
#     try:
#         i = 0
#         file_rot = ori_path + '/' + file
#         ori = cv2.imread(file_rot, cv2.COLOR_BGR2RGB)
#         save_rot = save_path + '/' + str(i) + '_' + file
#         i += 1
#         img90 = cv2.rotate(ori, cv2.ROTATE_90_CLOCKWISE) # 시계방향으로 90도 회전
#         cv2.imwrite(save_rot, img90)
#         save_rot = save_path + '/' + str(i) + '_' + file
#         i += 1
#         img180 = cv2.rotate(ori, cv2.ROTATE_180) # 180도 회전
#         cv2.imwrite(save_rot, img180)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img270 = cv2.rotate(ori, cv2.ROTATE_90_COUNTERCLOCKWISE) # 반시계방향으로 90도 회전 
#         cv2.imwrite(save_rot, img270)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_RL_flip = cv2.flip(ori, 1)
#         cv2.imwrite(save_rot, img_RL_flip)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_TB_flip = cv2.flip(ori, 0)
#         cv2.imwrite(save_rot, img_TB_flip)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie1 = cv2.resize(ori, None, fx = 0.5, fy = 1)
#         cv2.imwrite(save_rot, img_rezie1)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie2 = cv2.resize(ori, None, fx = 1, fy = 0.5)
#         cv2.imwrite(save_rot, img_rezie2)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie3 = cv2.resize(img180, None, fx = 0.5, fy = 1)
#         cv2.imwrite(save_rot, img_rezie3)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie4 = cv2.resize(img180, None, fx = 1, fy = 0.5)
#         cv2.imwrite(save_rot, img_rezie4)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie5 = cv2.resize(img90, None, fx = 0.5, fy = 1)
#         cv2.imwrite(save_rot, img_rezie5)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie6 = cv2.resize(img90, None, fx = 1, fy = 0.5)
#         cv2.imwrite(save_rot, img_rezie6)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie7 = cv2.resize(img_RL_flip, None, fx = 0.5, fy = 1)
#         cv2.imwrite(save_rot, img_rezie7)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie8 = cv2.resize(img_RL_flip, None, fx = 1, fy = 0.5)
#         cv2.imwrite(save_rot, img_rezie8)
#         save_rot = save_path + '/' + str(i) + '_' + file 
#         i += 1
#         img_rezie9 = cv2.resize(img_TB_flip, None, fx = 0.5, fy = 1)
#         cv2.imwrite(save_rot, img_rezie9)
#     except:
#         continue

# print('end')
# Out:
# ['0_beanleaf (1).jpg', '0_beanleaf (10).jpg', '0_beanleaf (100).jpg', '0_beanleaf (101).jpg', '0_beanleaf (104).jpg', '0_beanleaf (105).jpg', '0_beanleaf (106).jpg', '0_beanleaf (107).jpg', '0_beanleaf (108).jpg', '0_beanleaf (109).jpg', '0_beanleaf (11).jpg', '0_beanleaf (111).jpg', '0_beanleaf (114).jpg', '0_beanleaf (119).jpg', '0_beanleaf (12).jpg', '0_beanleaf (120).jpg', '0_beanleaf (121).jpg', '0_beanleaf (122).jpg', '0_beanleaf (123).jpg', '0_beanleaf (125).jpg', '0_beanleaf (128).jpg', '0_beanleaf (129).jpg', '0_beanleaf (13).jpg', '0_beanleaf (134).jpg', '0_beanleaf (135).jpg', '0_beanleaf (136).jpg', '0_beanleaf (137).jpg', '0_beanleaf (138).jpg', '0_beanleaf (139).jpg', '0_beanleaf (14).jpg', '0_beanleaf (140).jpg', '0_beanleaf (143).jpg', '0_beanleaf (148).jpg', '0_beanleaf (149).jpg', '0_beanleaf (15).jpg', '0_beanleaf (150).jpg', '0_beanleaf (155).jpg', '0_beanleaf (157).jpg', '0_beanleaf (16).jpg', '0_beanleaf (161).jpg', '0_beanleaf (162).jpg', '0_beanleaf (164).jpg'
# ...
